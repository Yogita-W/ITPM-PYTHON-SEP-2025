# %%
import pandas as pd

# %%
df1 = pd.read_csv("/kaggle/input/datasets/dhrubangtalukdar/mercedes-global-car-sales-2020-2025/mercedes_benz_sales_2020_2025.csv")
df1
# Out:
#              Model  Year  Region   Color Fuel Type  Base Price (USD)  \
# 0          A-Class  2020  Global  Yellow    Diesel             41265
# 1          A-Class  2020  Global   Black    Petrol             51023
# 2          A-Class  2020  Global    Grey    Petrol             72819
# 3          A-Class  2020  Global   Black    Petrol             62480
# 4          A-Class  2020  Global   White    Petrol             35189
# ...            ...   ...     ...     ...       ...               ...
# 12132661  AMG S 63  2025  Global  Silver  Electric            219647
# 12132662  AMG S 63  2025  Global    Grey  Electric            251632
# 12132663  AMG S 63  2025  Global    Grey    Hybrid            260947
# 12132664  AMG S 63  2025  Global    Grey  Electric            311030
# 12132665  AMG S 63  2025  Global  Silver  Electric            383516
#
#           Horsepower  Sales Volume Turbo
# 0                252             1   Yes
# 1                249             1    No
# ...

# %%
df1.isnull().sum()
# Out:
# Model               0
# Year                0
# Region              0
# Color               0
# Fuel Type           0
# Base Price (USD)    0
# Horsepower          0
# Sales Volume        0
# Turbo               0
# dtype: int64

# %%
df2 = pd.read_csv("/kaggle/input/datasets/ronakbokaria/myntra-products-dataset/myntra202305041052.csv")
df2
# Out:
#               id                                    name  \
# 0              1              Men Solid Oversized Cotton
# 1              2          Men Cotton Pure Cotton T-shirt
# 2              3               Women Pure Cotton T-shirt
# 3              4                Typography Print T-shirt
# 4              5  Printed Round Neck Pure Cotton T-shirt
# ...          ...                                     ...
# 1060208  1060209              Men Slim Tapered Fit Jeans
# 1060209  1060210                    Men Skinny Fit Jeans
# 1060210  1060211                      Men Printed Shorts
# 1060211  1060212                    Men Skinny Fit Jeans
# 1060212  1060213                               Men Jeans
#
#                                                        img asin   price  \
# 0        https://assets.myntassets.com/f_webp,dpr_1.0,q...    -   532.0
# 1        https://assets.myntassets.com/f_webp,dpr_1.0,q...    -   274.0
# ...

# %%
df2.head()
# Out:
#    id                                    name  \
# 0   1              Men Solid Oversized Cotton
# 1   2          Men Cotton Pure Cotton T-shirt
# 2   3               Women Pure Cotton T-shirt
# 3   4                Typography Print T-shirt
# 4   5  Printed Round Neck Pure Cotton T-shirt
#
#                                                  img asin  price     mrp  \
# 0  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  532.0  1299.0
# 1  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  274.0   499.0
# 2  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  551.0  1199.0
# 3  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  296.0  1099.0
# 4  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  494.0   899.0
#
#    rating  ratingTotal  discount                 seller  \
# 0     4.1         5300        59  Difference of Opinion
# 1     4.2        25400        45               Roadster
# 2     4.5         3400        54              DILLINGER
# ...

# %%
df2.tail()
# Out:
#               id                        name  \
# 1060208  1060209  Men Slim Tapered Fit Jeans
# 1060209  1060210        Men Skinny Fit Jeans
# 1060210  1060211          Men Printed Shorts
# 1060211  1060212        Men Skinny Fit Jeans
# 1060212  1060213                   Men Jeans
#
#                                                        img asin   price  \
# 1060208  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  1199.0
# 1060209  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -   574.0
# 1060210  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -   799.0
# 1060211  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  1199.0
# 1060212  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -   835.0
#
#             mrp  rating  ratingTotal  discount          seller  \
# 1060208  2399.0     4.3           44        50  Flying Machine
# 1060209  2299.0     3.8           34        75  Mast & Harbour
# 1060210  1599.0     3.9            8        50    WROGN ACTIVE
# ...

# %%
df2.head(20)
# Out:
#     id                                       name  \
# 0    1                 Men Solid Oversized Cotton
# 1    2             Men Cotton Pure Cotton T-shirt
# 2    3                  Women Pure Cotton T-shirt
# 3    4                   Typography Print T-shirt
# 4    5     Printed Round Neck Pure Cotton T-shirt
# 5    6                     Boys Pack of 5 T-shirt
# 6    7     Polo Collar Cotton Pure Cotton T-shirt
# 7    8             Boys Pack Of 5 Printed T-shirt
# 8    9                Printed Pure Cotton T-shirt
# 9   10     Printed Round Neck Pure Cotton T-shirt
# 10  11     Printed Round Neck Pure Cotton T-shirt
# 11  12             Longline T-shirt with Raw Edge
# 12  13      Printed Oversized Pure Cotton T-shirt
# 13  14       Men Camouflage Printed Loose T-shirt
# 14  15  Time Travlr Sleveless Pure Cotton T-shirt
# 15  16            Men Striped Polo Collar T-shirt
# 16  17            Men Striped Polo Collar T-shirt
# 17  18                        Henley Neck T-shirt
# ...

# %%
df2
# Out:
#               id                                    name  \
# 0              1              Men Solid Oversized Cotton
# 1              2          Men Cotton Pure Cotton T-shirt
# 2              3               Women Pure Cotton T-shirt
# 3              4                Typography Print T-shirt
# 4              5  Printed Round Neck Pure Cotton T-shirt
# ...          ...                                     ...
# 1060208  1060209              Men Slim Tapered Fit Jeans
# 1060209  1060210                    Men Skinny Fit Jeans
# 1060210  1060211                      Men Printed Shorts
# 1060211  1060212                    Men Skinny Fit Jeans
# 1060212  1060213                               Men Jeans
#
#                                                        img asin   price  \
# 0        https://assets.myntassets.com/f_webp,dpr_1.0,q...    -   532.0
# 1        https://assets.myntassets.com/f_webp,dpr_1.0,q...    -   274.0
# ...

# %%
df2.columns
# Out:
# Index(['id', 'name', 'img', 'asin', 'price', 'mrp', 'rating', 'ratingTotal',
#        'discount', 'seller', 'purl'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060213 entries, 0 to 1060212
# Data columns (total 11 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1060213 non-null  int64
#  1   name         1060213 non-null  object
#  2   img          1060213 non-null  object
#  3   asin         1060213 non-null  object
#  4   price        1060213 non-null  float64
#  5   mrp          1060213 non-null  float64
#  6   rating       1060213 non-null  float64
#  7   ratingTotal  1060213 non-null  int64
#  8   discount     1060213 non-null  int64
#  9   seller       1060213 non-null  object
#  10  purl         1060213 non-null  object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 89.0+ MB

# %%
df2.shape
# Out:
# (1060213, 11)

# %%
df2.size
# Out:
# 11662343

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060213 entries, 0 to 1060212
# Data columns (total 11 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1060213 non-null  int64
#  1   name         1060213 non-null  object
#  2   img          1060213 non-null  object
#  3   asin         1060213 non-null  object
#  4   price        1060213 non-null  float64
#  5   mrp          1060213 non-null  float64
#  6   rating       1060213 non-null  float64
#  7   ratingTotal  1060213 non-null  int64
#  8   discount     1060213 non-null  int64
#  9   seller       1060213 non-null  object
#  10  purl         1060213 non-null  object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 89.0+ MB

# %%
df2.isnull().sum()
# Out:
# id             0
# name           0
# img            0
# asin           0
# price          0
# mrp            0
# rating         0
# ratingTotal    0
# discount       0
# seller         0
# purl           0
# dtype: int64

# %% [markdown]
# 1.df
# 2.head()
# 3.tail()
# 4.info()
# 5.columns
# 6.shape
# 7.size
# 9.isnull

# %%
df2.describe()
# Out:
#                  id         price           mrp        rating   ratingTotal  \
# count  1.060213e+06  1.060213e+06  1.060213e+06  1.060213e+06  1.060213e+06
# mean   5.301070e+05  1.536235e+03  2.668379e+03  1.060150e+00  4.189618e+01
# std    3.060573e+05  3.051140e+03  3.877900e+03  1.829632e+00  7.476645e+02
# min    1.000000e+00  2.500000e+01  2.500000e+01  0.000000e+00  0.000000e+00
# 25%    2.650540e+05  4.990000e+02  9.990000e+02  0.000000e+00  0.000000e+00
# 50%    5.301070e+05  8.110000e+02  1.780000e+03  0.000000e+00  0.000000e+00
# 75%    7.951600e+05  1.497000e+03  2.999000e+03  2.800000e+00  3.000000e+00
# max    1.060213e+06  2.575000e+05  2.575000e+05  5.000000e+00  7.640000e+04
#
#            discount
# count  1.060213e+06
# mean   1.496420e+02
# std    5.648781e+02
# min    0.000000e+00
# 25%    1.500000e+01
# 50%    5.000000e+01
# 75%    6.800000e+01
# max    1.999600e+04

# %%
print(df2["id"].count())
# Out:
# 1060213

# %%
df2["mrp"].min()
# Out:
# 25.0

# %%
df2["mrp"].max()
# Out:
# 257500.0

# %%
print(df2["mrp"].mean())
# Out:
# 2668.3793342847134

# %%
df2.columns
# Out:
# Index(['id', 'name', 'img', 'asin', 'price', 'MRP', 'rating', 'ratingTotal',
#        'discount', 'seller', 'purl'],
#       dtype='object')

# %%
df2.rename(columns = {"mrp":"MRP"},inplace = True)
df2.columns
# Out:
# Index(['id', 'name', 'img', 'asin', 'price', 'MRP', 'rating', 'ratingTotal',
#        'discount', 'seller', 'purl'],
#       dtype='object')

# %%
df2.drop(columns = {"img"},inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_55/3992787257.py in <cell line: 0>()
# ----> 1 df2.drop(columns = {"img"},inplace = True)
#       2 df2.columns
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df2.columns
# Out:
# Index(['id', 'name', 'asin', 'price', 'MRP', 'rating', 'ratingTotal',
#        'discount', 'seller', 'purl'],
#       dtype='object')
