# %%
with open("Demo.txt",'r') as file :
    data = file.readline()
    print(data)
    print(data[6:])
# Out:
# I like Python
#
#  Python

# %%
print(data)
# Out:
# I like Python

# %%
file.close()
print(data)
# Out:
# I like Python

# %%
with open("Demo.txt","r") as file1 :
    content = file1.read()
    print(file.close())
# Out:
# None

# %%
file1.close()
print(content)
# Out:
# I like Python
# I learn Python
# I like Coding
