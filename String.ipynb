# %%
print("helloo")
# Out:
# helloo

# %% [markdown]
# string : string is collection on char.
# Create string : str1 = ' '
#                 str2 = " "
#                 str3 = '''  '''

# %% [markdown]
# string functions:
# 1.upper
# 2.lower
# 3.capitalize
# 4.title
# 5.strip
# 6.replace
# 7.indexing
# 8.slicing
# 9.len
# 10.sorted
# 11.del

# %%
str1 = ' Yogita'
str2 = " Yogita "
str3 = ''' Yogita '''
print(str1)
print(str2)
print(str3)
# Out:
#  Yogita
#  Yogita
#  Yogita

# %%
str4 = '[1,2,3,4]'
print(str4)
print(type(str4))

# %%
str5 = "I like python Programming 12 2.3 @ % {1,2,3} [4,5,6]"
str5

# %%
Name = 'rohan'
print(Name)

# %%
#upper
print(Name.upper())
print(Name)
# Out:
# ROHAN
# rohan

# %%
Names = 'Om Pravin ABhjit hArsh'
print(Names.upper())
print(Names.lower())
# Out:
# OM PRAVIN ABHJIT HARSH
# om pravin abhjit harsh

# %%
str2 = "i like python programming"
print(str2.capitalize())

# %%
str2.title()
# Out:
# 'I Like Python Programming'

# %%
address = '                                   Pune'
print(address)
print(address.strip())
# Out:
#                                    Pune
# Pune

# %%
names = "              Vishakha             Sayli"
names.strip()
# Out:
# 'Vishakha             Sayli'

# %%
str1 = "Python"
str2 = "Programming"
print(str1+" "+str2)
# Out:
# Python Programming

# %%
print(str1 *10)
print((str1+" ")*10)
# Out:
# PythonPythonPythonPythonPythonPythonPythonPythonPythonPython
# Python Python Python Python Python Python Python Python Python Python

# %%
Std_details = "I am Om and am from Tuljapur "
print("Tuljapur" in Std_details)
# Out:
# True

# %%
print(Std_details.replace("Tuljapur","Pune"))
print(Std_details)
# Out:
#  I am Om and am from Pune
#  I am Om and am from Tuljapur

# %%
print(Std_details)
print(Std_details[3])
print(Std_details[-2])
# Out:
# I am Om and am from Tuljapur
# m
# r

# %%
print(Std_details[5:14])
# Out:
# Om and am

# %%
print(Std_details)
print(Std_details[::-1])
print(Std_details[::2])
# Out:
# I am Om and am from Tuljapur
#  rupajluT morf ma dna mO ma I
# Ia mada rmTlau

# %%
len(Std_details)
# Out:
# 29

# %%
#Wap to check string are palimdrom or not.
str1 = input("Enter a string")
if str1==str1[::-1]:
    print(f"{str1} is a palimdrom String")
else : 
    print(f"{str1} is not a palimdrom String")
# Out:
# level is a palimdrom String

# %%
x = 121
print(x[::-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 2
#       1 x = 121
# ----> 2 print(x[::-1])
#
# TypeError: 'int' object is not subscriptable

# %%
Number = int(input("Enter a number"))
Temp = Number 
reversed = 0
while Number>0:
    digit = Number%10
    reversed = reversed*10+digit
    Number=Number//10
print(Temp)
print(reversed)    
if Temp == reversed:
    print(f"{Temp} is Palimdrom")
else :
    print(f"{Temp} is not Palimdrom")
# Out:
# 121
# 121
# 121 is Palimdrom

# %%
#

# %% [markdown]
# wap to conver all lower case into upper case from given string and all upper case into lower case.EX:I/P: i aM yOGITA O/P: I Am Yogita
# wap to check given strings are angram or not
# Wap to this output str1 = "I like python programming"
#                     # o/p : "programming python like I"
# wap to check is python word present in string or not if its present then chenge it with python programming.
# Ex : I/p : I like Python and I Study it o/p: I like Python Programming and I Study it

# %%
Name = Names.lower()
Name
# Out:
# 'om pravin abhjit harsh'

# %%
print(Name)
print(sorted(Name))
# Out:
# om pravin abhjit harsh
# [' ', ' ', ' ', 'a', 'a', 'a', 'b', 'h', 'h', 'h', 'i', 'i', 'j', 'm', 'n', 'o', 'p', 'r', 'r', 's', 't', 'v']

# %%
Name.count('a')
# Out:
# 3

# %%
Marks = '[12,32,4,65,43]'
min(Marks)
# Out:
# ','

# %%
str1 = " I like Python "
print(sorted(str1))
print(max(str1))
print(min(str1))
# Out:
# [' ', ' ', ' ', ' ', 'I', 'P', 'e', 'h', 'i', 'k', 'l', 'n', 'o', 't', 'y']
# y

# %%
str2 = "abcdcsxyz"
max(str2)
min(str2)
# Out:
# 'a'

# %%
str2.clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 str2.clear()
#
# AttributeError: 'str' object has no attribute 'clear'

# %%
del str2
str2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 del str2
#       2 str2
#
# NameError: name 'str2' is not defined

# %%
print(Name)
print(Name.append(a))
# Out:
# om pravin abhjit harsh
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 2
#       1 print(Name)
# ----> 2 print(Name.append(a))
#
# AttributeError: 'str' object has no attribute 'append'
