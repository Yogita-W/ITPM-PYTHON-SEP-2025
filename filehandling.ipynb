# %%
with open("Demo.txt","r") as file : # open file
    Data = file.read() # read file and store data in variable(Data)
    print(Data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 with open("Demo.txt","r") as file : # open file
#       2     Data = file.read() # read file and store data in variable(Data)
#       3     print(Data)
#
# TypeError: 'str' object is not callable

# %%
with open("hello.py") as python_file :
    code = python_file.read()
    print(code)
# Out:
# print("hello World")

# %%
with open("Demo.txt","w") as file :
    Data = file.write("I learn Python") 
with open("Demo.txt","r")  as file:
    R1 = file.read()     
    print(R1)
# Out:
# I learn Python

# %%
with open("Demo.txt","a") as file :
    add = file.write("\nI learn UI Also")

with open("Demo.txt","r") as file:
    data = file.read()
    print(data)
# Out:
# I learn Python
# I learn UI Also
# I learn UI Also
# I learn UI Also
#  I learn UI Also

# %%
with open("Demo.txt","r+") as file:
    content = file.write("I like Python")
    R1 = file.read()
    print(R1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 with open("Demo.txt","r+") as file:
#       2     content = file.write("I like Python")
#       3     R1 = file.read()
#
# TypeError: 'str' object is not callable

# %%
with open("Demo.txt","r") as file:
    data = file.read()
    print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 with open("Demo.txt","r") as file:
#       2     data = file.read()
#       3     print(data)
#
# TypeError: 'str' object is not callable
