# %%
pip install pasdas

# %% [markdown]
# Pandas functions :
# 1.read_csv()
# 2.head()
# 3.tail()
# 4.size()
# 5.shape
# 6.describe()
# 7.columns()
# 8.info()
# 9.isnull()
# 10.isnull().sum()
# 11.rename()
# 12.drop()
# 13.max()
# 14.min()
# 15.count()
# 16.duplicated()
# 17.len()
# 18.std()
# 19.var()
# 20.

# %%
import pandas as pd

# %%
series = pd.Series([1,2,3,4,5])
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
Name  = pd.Series(["Sayli","Harshda","Vishakha","Yashu","Om","Rahul"])
Name
# Out:
# 0       Sayli
# 1     Harshda
# 2    Vishakha
# 3       Yashu
# 4          Om
# 5       Rahul
# dtype: object

# %%
df = pd.DataFrame([[1,2,3],[4,5,6]])
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
dict = {"Name": ["Sayli","Harshda","Vishakha","Yashu","Om","Rahul"],
        "Marks": [95,96,94,90,90,95]}
print(dict)
df1 = pd.DataFrame(dict)
df1
# Out:
# {'Name': ['Sayli', 'Harshda', 'Vishakha', 'Yashu', 'Om', 'Rahul'], 'Marks': [95, 96, 94, 90, 90, 95]}
#        Name  Marks
# 0     Sayli     95
# 1   Harshda     96
# 2  Vishakha     94
# 3     Yashu     90
# 4        Om     90
# 5     Rahul     95

# %%
s1 = pd.Series([1,2,3,4,5])
s1

# %%
s2 = pd.Series(["Vaishnavi","Rutuja","Priya","trupti","Ankita","Sayli"])
s2

# %%
l1 = [43.4,65.5,44.6,33,32.54]
print(l1)
s3 = pd.Series(l1)
print(s3)

# %%
import numpy as np
arr1 = np.array([10,9,8,7,6])
print(arr1)
Ser1 = pd.Series(arr1)
print(Ser1)

# %%
arr2 = np.array([[1,2,3],[4,5,6]])
print(arr2)
Ser2 = pd.Series(arr2)
print(Ser2)

# %%
arr2 = np.array([[1,2,3],[4,5,6]])
print(arr2)
Ser2 = pd.DataFrame(arr2)
print(Ser2)

# %%
dict1 = {"Name":["Ankit","Sandesh","Gaurav","Sanket","Prnav","Adi","Sushant"],
         "Marks":[30,32,35,40,43,40,42]}
df = pd.DataFrame(dict1)
print(df)

# %%
df1 = pd.read_csv()

# %%
#Creating Df using Csv file
df1 = pd.read_csv("/kaggle/input/home-loan-approval/loan_sanction_test.csv")
df1

# %%
df1

# %%
#syntax for Vc cod
df1 = pd.read_csv("loan_sanction_test.csv")
df1

# %%
df1.head()

# %%
df1.tail()

# %%
#Creating df using Excel.
df2 = pd.read_excel("/kaggle/input/excel-file/excel styles.xlsx")
df2

# %%
df1.head(20)

# %%
df1.tail(10)

# %%
df1.shape

# %%
df1.columns

# %%
df1.info()

# %%
df1.shape

# %%
df1.size

# %%
df1.isnull().sum()

# %% [markdown]
# 1.head
# 2.tail
# 3.column
# 4.info
# 5.shape
# 6.size
# 7.isnull
# 8.isnull.sum()

# %%
df1.describe()

# %%
import pandas as pd

# %%
df1 = pd.read_csv("/kaggle/input/home-loan-approval/loan_sanction_test.csv")
df1
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# ...

# %%
df1.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df1['ApplicantIncome'].max()
# Out:
# 72529

# %%
df1['ApplicantIncome'].min()
# Out:
# 0

# %%
df1['CoapplicantIncome'].max()
# Out:
# 24000

# %%
df1['CoapplicantIncome'].min()
# Out:
# 0

# %%
df1['CoapplicantIncome'].mean()
# Out:
# 1569.5776566757493

# %%
df1['ApplicantIncome'].mean()
# Out:
# 4805.599455040872

# %%
df1['ApplicantIncome'].median()
# Out:
# 3786.0

# %%
import numpy as np 
array1 = np.array([1,2,3,4,5,6])
print(array1)
print(array1.mean())
print(array1.median())
# Out:
# [1 2 3 4 5 6]
# 3.5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_37/3903900669.py in <cell line: 0>()
#       3 print(array1)
#       4 print(array1.mean())
# ----> 5 print(array1.median())
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
df1['ApplicantIncome'].count()
# Out:
# 367

# %%
df1['ApplicantIncome'].std()
# Out:
# 4910.685398980398

# %%
df1['ApplicantIncome'].var()
# Out:
# 24114831.087759264

# %%
len(df1)
# Out:
# 367

# %%
df1.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
df1=df1.drop(['Property_Area'] ,axis=1)
df1.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
df1=df1.drop(columns=['Loan_Amount_Term'])
df1.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Credit_History'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'AppI', 'CoapplicantIncome', 'LoanAmount',
#        'Credit_History'],
#       dtype='object')

# %%
df1=df1.rename(columns = {'ApplicantIncome':'AppI'})
df1.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'AppI', 'CoapplicantIncome', 'LoanAmount',
#        'Credit_History'],
#       dtype='object')

# %%
df1.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#     Loan_ID Gender Married Dependents     Education Self_Employed  AppI  \
# 0  LP001015   Male     Yes          0      Graduate            No  5720
# 1  LP001022   Male     Yes          1      Graduate            No  3076
# 2  LP001031   Male     Yes          2      Graduate            No  5000
# 3  LP001035   Male     Yes          2      Graduate            No  2340
# ...

# %%
df1[200:211]
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       Loan_ID  Gender Married Dependents     Education Self_Employed  AppI  \
# 200  LP002105    Male     Yes          0      Graduate           Yes  8706
# 201  LP002107    Male     Yes         3+  Not Graduate            No  2855
# 202  LP002111    Male     Yes        NaN      Graduate            No  3016
# 203  LP002117  Female     Yes          0      Graduate            No  3159
# ...

# %%
df1[8:10]
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed   AppI  \
# 8  LP001059   Male     Yes          2      Graduate           NaN  13633
# 9  LP001067   Male      No          0  Not Graduate            No   2400
#
#    CoapplicantIncome  LoanAmount  Credit_History
# 8                  0       280.0             1.0
# 9               2400       123.0             1.0

# %%
df1.iloc[8]
# Out:
# Loan_ID              LP001059
# Gender                   Male
# Married                   Yes
# Dependents                  2
# Education            Graduate
# Self_Employed             NaN
# AppI                    13633
# CoapplicantIncome           0
# LoanAmount              280.0
# Credit_History            1.0
# Name: 8, dtype: object

# %%
df1.iloc[8:10]
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed   AppI  \
# 8  LP001059   Male     Yes          2      Graduate           NaN  13633
# 9  LP001067   Male      No          0  Not Graduate            No   2400
#
#    CoapplicantIncome  LoanAmount  Credit_History
# 8                  0       280.0             1.0
# 9               2400       123.0             1.0

# %%
ser1 = pd.Series([1,2,3,4,5],index = ['A','B','C','D','E'])
ser1
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   AppI               367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Credit_History     338 non-null    float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 28.8+ KB

# %%
df1.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# AppI                  0
# CoapplicantIncome     0
# LoanAmount            5
# Credit_History       29
# dtype: int64

# %%
df2 = df1.fillna(0)
df2.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# AppI                 0
# CoapplicantIncome    0
# LoanAmount           0
# Credit_History       0
# dtype: int64

# %%
dict1 = {"Marks" : [12,32,43," ",54,76," ",9]}
d1 = pd.DataFrame(dict1)
d1
# Out:
#   Marks
# 0    12
# 1    32
# 2    43
# 3
# 4    54
# 5    76
# 6
# 7     9

# %%
d1.isnull().sum()
# Out:
# Marks    0
# dtype: int64

# %%
#create df
import pandas as pd
df = pd.read_csv("/kaggle/input/home-loan-approval/loan_sanction_test.csv")
df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# ...

# %% [markdown]
# 1.read_csv()
# 2.head()

# %%
df.tail()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# ...

# %%
df.head(10)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001015    Male     Yes          0      Graduate            No
# 1  LP001022    Male     Yes          1      Graduate            No
# 2  LP001031    Male     Yes          2      Graduate            No
# 3  LP001035    Male     Yes          2      Graduate            No
# ...

# %%
df.tail(20)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 347  LP002885    Male      No          0  Not Graduate            No
# 348  LP002890    Male     Yes          2  Not Graduate            No
# 349  LP002891    Male     Yes          0      Graduate           Yes
# 350  LP002899    Male     Yes          2      Graduate            No
# ...

# %%
df.shape
# Out:
# (367, 12)

# %%
df.size
# Out:
# 4404

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
df["Loan_ID"].count()
# Out:
# 367

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#missing values
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
df.drop(columns = {"Property_Area"},inplace = True)
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
df.drop(columns = {'Loan_Amount_Term', 'Credit_History'},inplace = True)
df.columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_38/3764533925.py in <cell line: 0>()
# ----> 1 df.drop(columns = {'Loan_Amount_Term', 'Credit_History'},inplace = True)
#       2 df.columns
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount'],
#       dtype='object')

# %%
df.rename(columns = {'Loan_ID':'Id'},inplace = True)

# %%
df.columns
# Out:
# Index(['Id', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount'],
#       dtype='object')

# %%
df['ApplicantIncome'].max()
# Out:
# 72529

# %%
df['ApplicantIncome'].min()
# Out:
# 0

# %%
df['Id'].count()
# Out:
# 367

# %%
df.duplicated().sum()
# Out:
# 0

# %%
len(df['Id'])
# Out:
# 367

# %%
df['ApplicantIncome'].var()
# Out:
# 24114831.087759264

# %%
df['ApplicantIncome'].std()
# Out:
# 4910.685398980398

# %%
df['ApplicantIncome'].mean()
# Out:
# 4805.599455040872

# %%
df['ApplicantIncome'].median()
# Out:
# 3786.0

# %%
df['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
df.isnull().sum()
# Out:
# Id                    0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# dtype: int64

# %%
df1 = df.fillna(0)
df1.isnull().sum()
# Out:
# Id                   0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Id                    0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# dtype: int64

# %%
df.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_38/3698961737.py in <cell line: 0>()
# ----> 1 df.mean()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
df['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
df.isnull().sum()
# Out:
# Id                     0
# Gender               367
# Married                0
# Dependents            10
# Education              0
# Self_Employed         23
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount             5
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_38/3971990979.py in <cell line: 0>()
# ----> 1 df['Gender'] = df.fillna('Male')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
# -> 4301             self._set_item_frame_value(key, value)
#    4302         elif (
#    4303             is_list_like(value)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    4427             len_cols = 1 if is_scalar(cols) or isinstance(cols, tuple) else len(cols)
#    4428             if len_cols != len(value.columns):
# -> 4429                 raise ValueError("Columns must be same length as key")
#    4430
# ...

# %%
df['LoanAmount'].mean()
# Out:
# nan

# %%
df.head()
# Out:
#          Id      Gender Married Dependents     Education Self_Employed  \
# 0  LP001015  136.132597     Yes          0      Graduate            No
# 1  LP001022  136.132597     Yes          1      Graduate            No
# 2  LP001031  136.132597     Yes          2      Graduate            No
# 3  LP001035  136.132597     Yes          2      Graduate            No
# 4  LP001051  136.132597      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome LoanAmount
# 0             5720                  0       None
# 1             3076               1500       None
# 2             5000               1800       None
# 3             2340               2546       None
# 4             3276                  0       None

# %%
df['LoanAmount'] = df.fillna(df['LoanAmount'].mean(),inplace = True)
# Out:
# /tmp/ipykernel_38/1315503678.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['LoanAmount'] = df.fillna(df['LoanAmount'].mean(),inplace = True)

# %%
df[''.isnull().sum()
# Out:
# Id                     0
# Gender                 0
# Married                0
# Dependents             0
# Education              0
# Self_Employed          0
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount           367
# dtype: int64
