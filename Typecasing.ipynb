# %%
x = 5
x
# Out:
# 5

# %%
x = 6 # 6.0
y = 3.4 # 3.4
print(x+y)
# Out:
# 9.4

# %%
x = "om"
y =  23
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 x = "om"
#       2 y =  23
# ----> 3 print(x+y)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Types of TypeCasting : 1.Immplisite type casting (automatic)
#                        2.Explisite type casing(manully change)

# %% [markdown]
# 1.Immpliste Type casing:
#                          1.int
#                          2.float
#                          3.complex
#                          4.bool

# %%
#int+flpoat
x = 2
y = 3.4
print(x+y)
# Out:
# 5.4

# %%
#int+complex
x = 23
y = 2+3j
print(x+y)
# Out:
# (25+3j)

# %%
#int+bool
x = 10
y = True
print(x+y)
# Out:
# 11

# %%
#int into flaot
x = 2
y = float(x)
print(y)
print(type(y))
# Out:
# 2.0
# <class 'float'>

# %%
#int into complex number.
x = 20
C = complex(x)
C
# Out:
# (20+0j)

# %%
#int into bool
x = 0
y = bool(x)
y
# Out:
# False

# %%
# int into list
x = 45
list1 = list(x)
list1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # int into list
#       2 x = 45
# ----> 3 list1 = list(x)
#       4 list1
#
# TypeError: 'int' object is not iterable

# %%
set = set(x)
set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 set = set(x)
#       2 set
#
# TypeError: 'int' object is not iterable

# %%
str1 = str(x)
str1
# Out:
# '45'

# %%
x=10
y=20
x+y
# Out:
# 30

# %%
s_x = str(x)
s_y = str(y)
s_x+s_y
# Out:
# '1020'

# %% [markdown]
# 2.Expliste type Casting:
#                         1.string
#                         2.List
#                         3.set
#                         4.tuple
#                         5.dictionary

# %%
str1 = "Python python"
list1 = list(str1)
list1
# Out:
# ['P', 'y', 't', 'h', 'o', 'n', ' ', 'p', 'y', 't', 'h', 'o', 'n']

# %%
str2 = "Programming"
list2 = ['P','y','t','h','o','n']
print(list(str2)+list2)
# Out:
# ['P', 'r', 'o', 'g', 'r', 'a', 'm', 'm', 'i', 'n', 'g', 'P', 'y', 't', 'h', 'o', 'n']

# %%
list2
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %%
str3 = str(list2)
str3
# Out:
# "['P', 'y', 't', 'h', 'o', 'n']"

# %%
#string to set
print(str1)
set = set(str1)
set
# Out:
# Python python
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 #string to set
#       2 print(str1)
# ----> 3 set = set(str1)
#       4 set
#
# TypeError: 'set' object is not callable

# %%
string1 = "aaaaaaaaaaaaaaaaaaaaaaaaaaaa"
set = set(string1)
set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 string1 = "aaaaaaaaaaaaaaaaaaaaaaaaaaaa"
# ----> 2 set = set(string1)
#       3 set
#
# TypeError: 'set' object is not callable

# %%
str1 ="abcdefgh"
set = set(list(str1))
set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 str1 ="abcdefgh"
# ----> 2 set = set(list(str1))
#       3 set
#
# TypeError: 'set' object is not callable

# %%
str1 = "abcdefgh"
l1 = list(str1)
print(l1)
s1 = set(l1)
s1
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 4
#       2 l1 = list(str1)
#       3 print(l1)
# ----> 4 s1 = set(l1)
#       5 s1
#
# TypeError: 'set' object is not callable

# %%
string = "Python"
s1 = set(string)
s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 string = "Python"
# ----> 2 s1 = set(string)
#       3 s1
#
# TypeError: 'set' object is not callable

# %% [markdown]
# Expliste data type combunations:
#     string                                       list
# 1.string----list(YES)                            1.List------string(YES)
# 2.string----set(YES)                             2.List-------Set(YES)
# 3.string----tuple(YES)                           3.List-------Tuple(YES)
# 4.string-----dict(NO)                            4.List--------dict(NO)
#
#          Set                                        Tuple
# 1.Set----list(YES)                               1.Tuple------string(YES)
# 2.Set----string(YES)                             2.Tuple-------Set(YES)
# 3.Set----tuple(YES)                              3.Tuple-------LIST(YES)
# 4.Set-----dict(NO)                               4.Tuple--------dict(NO)
#
#                                 Dictionary
#                              1.Dict-----String(YES..............)
#                              2.Dict-----List(YES)
#                              3.Dict-----Tuple(YES)
#                              4.Dict-----Set(YES)

# %%
Dict1 = {"Id":[1,2,3,4],
         "Name":["Om","jay","raj","Ansh"]}
str1 = str(Dict1)
str1
# Out:
# "{'Id': [1, 2, 3, 4], 'Name': ['Om', 'jay', 'raj', 'Ansh']}"

# %%
Dict1 = {"Id":[1,2,3,4],
         "Name":["Om","jay","raj","Ansh"]}
list1 =list(Dict1)
list1
# Out:
# ['Id', 'Name']

# %%
Dict1 = {"Id":[1,2,3,4],
         "Name":["Om","jay","raj","Ansh"]}
set = set(Dict1)
set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 Dict1 = {"Id":[1,2,3,4],
#       2          "Name":["Om","jay","raj","Ansh"]}
# ----> 3 set =set(Dict1)
#       4 set
#
# TypeError: 'set' object is not callable

# %%
Dict1 = {"Id":[1,2,3,4],
         "Name":["Om","jay","raj","Ansh"]}
tuple =tuple(Dict1)
tuple
# Out:
# ('Id', 'Name')
