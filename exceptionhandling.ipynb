# %%
x = int(input("Enter a number"))
y = int(input("Enter a number"))
z = x/y
print(z)
print("Thank you")

# %%
try : 
    x = int(input("Enter a number"))
    y = int(input("Enter a number"))
    z = x/y
except ZeroDivisionError :  
    print("Division with 0 not possible plz insert another number")

else :      
    print(z)
    
finally:    
   print("Thank you")
# Out:
# Division with 0 not possible plz insert another number
# Thank you

# %%
try :
    Account_number1 = int(input("Enter Account number"))
    Password1 = input("Enter your password")

except ValueError :
    print("Plz Enter Valid Account  number and password")
    
else :
    print("Login Successfully")
    
finally:
    print("Thank you")
# Out:
# Login Successfully
# Thank you

# %% [markdown]
# Types of Errors :
# 1.Compile Time Error
#       1.Indentation Error
#       2.Syntax error
# 2.Run time Error
#       1.Value Error
#       2.Zero Division Error
#       3.Index Error
#       4.Modul  not found Error
#       5.Type Error
#       6.

# %%
x = int(input("Enter a number"))
print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 x = int(input("Enter a number"))
#       2 print(x)
#
# ValueError: invalid literal for int() with base 10: 'ghdjhs'

# %%
x = [1,2,3]
print(x[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 x = [1,2,3]
# ----> 2 print(x[4])
#
# IndexError: list index out of range

# %%
import math1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import math1
#
# ModuleNotFoundError: No module named 'math1'

# %%
x = 12
y = "34"
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 x = 12
#       2 y = "34"
# ----> 3 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try : 
    x = int(input("Enter a number"))
    y = int(input("Enter a number"))
    z = x/y
except ZeroDivisionError :  
    print("Division with 0 not possible plz insert another number")
    
except ValueError:
    print("Plz Enter a valid Number")    

else :      
    print(z)
    
finally:    
   print("Thank you")
# Out:
# Plz Enter a valid Number
# Thank you

# %%
try :
    x = int(input("enter a number")) 
    list = [1,2,3,4,5,6]
    print(list[x])
    
except IndexError :
    print("plz enter index between 0 to 5")
# Out:
# plz enter index between 0 to 5

# %%
try :
    x = int(input("enter a number")) 
    list = [1,2,3,4,5,6]
    print(x in list)
    
except ValueError :
    print("plz enter valid number")
# Out:
# plz enter valid number

# %%
def Add(x,y):
    return x+y

Add(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 def Add(x,y):
#       2     return x+y
# ----> 4 Add(10,20,30)
#
# TypeError: Add() takes 2 positional arguments but 3 were given

# %%
try :
    x = int(input("enter number"))
    y = int(input("enter number"))
    def Add(x,y):
        return x+y
      
except TypeError:
    print("Enter valid Parameters ")    
    
else :
    Add(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 try :
# ----> 2     x = int(input("enter number"))
#       3     y = int(input("enter number"))
#       4     def Add(x,y):
#
# ValueError: invalid literal for int() with base 10: 'zxsjxsjxnmsnmsm'
